# %%
import pandas as pd
import numpy as np

# %%
credits = pd.read_csv("/content/tmdb_5000_credits.csv")
movies = pd.read_csv("/content/tmdb_5000_movies.csv")

# %% [markdown]
# # Pre-processing

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count
# 0  Enter the World of Pandora.  Avatar           7.2       11800

# %%
credits.head(100)["crew"]
# Out:
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#                             ...
# 95    [{"credit_id": "52fe4bbf9251416c910e4801", "de...
# 96    [{"credit_id": "56e8462cc3a368408400354c", "de...
# 97    [{"credit_id": "5921d321c3a368799b05933f", "de...
# 98    [{"credit_id": "52fe4783c3a36847f8139fa5", "de...
# 99    [{"credit_id": "5325b661c3a3683dbf002c16", "de...
# Name: crew, Length: 100, dtype: object

# %%
new_movies = movies.merge(credits, on="title")

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.shape
# Out:
# (4803, 4)

# %%
new_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4804     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807          0                                                 []
# 4808          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# ...                                                 ...     ...
# 4804                                                NaN    9367
# 4805                                                NaN   72766
# 4806  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4807                        http://shanghaicalling.com/  126186
# 4808                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 4804  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4805                                                 []                en
# 4806  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4807                                                 []                en
# 4808  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4804                               El Mariachi
# 4805                                 Newlyweds
# 4806                 Signed, Sealed, Delivered
# 4807                          Shanghai Calling
# 4808                         My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 4804  El Mariachi just wants to play his guitar and ...   14.269792
# 4805  A newlywed couple's honeymoon is upended by th...    0.642552
# 4806  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4807  When ambitious New York attorney Sam is sent t...    0.857008
# 4808  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  ... runtime  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
# ...                                                 ...  ...     ...
# 4804           [{"name": "Columbia Pictures", "id": 5}]  ...    81.0
# 4805                                                 []  ...    85.0
# 4806  [{"name": "Front Street Pictures", "id": 3958}...  ...   120.0
# 4807                                                 []  ...    98.0
# 4808  [{"name": "rusty bear entertainment", "id": 87...  ...    90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4804      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4805                                                 []  Released
# 4806           [{"iso_639_1": "en", "name": "English"}]  Released
# 4807           [{"iso_639_1": "en", "name": "English"}]  Released
# 4808           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 4804  He didn't come looking for trouble, but troubl...
# 4805  A newlywed couple's honeymoon is upended by th...
# 4806                                                NaN
# 4807                           A New Yorker in Shanghai
# 4808                                                NaN
#
#                                          title vote_average vote_count  \
# 0                                       Avatar          7.2      11800
# 1     Pirates of the Caribbean: At World's End          6.9       4500
# 2                                      Spectre          6.3       4466
# 3                        The Dark Knight Rises          7.6       9106
# 4                                  John Carter          6.1       2124
# ...                                        ...          ...        ...
# 4804                               El Mariachi          6.6        238
# 4805                                 Newlyweds          5.9          5
# 4806                 Signed, Sealed, Delivered          7.0          6
# 4807                          Shanghai Calling          5.7          7
# 4808                         My Date with Drew          6.3         16
#
#      movie_id                                               cast  \
# 0       19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1         285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2      206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3       49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4       49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...       ...                                                ...
# 4804     9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805    72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806   231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807   126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808    25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4804  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4805  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4806  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4807  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4808  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
# [4809 rows x 23 columns]

# %%
new_movies.head(4)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
#
# [4 rows x 23 columns]

# %%
#genre
#id
####

# %%
new_movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
#movies.head()

# %%
movies = new_movies

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies = movies[["movie_id","overview","title","genres","keywords", "cast", "crew"]]

# %%
new_movies["original_language"].value_counts()
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64

# %%
new_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 864.2+ KB

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# overview    3
# title       0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)
# Out:
# <ipython-input-19-4d2d825739df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
'[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
def convert (obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i["name"])
    return L

# %%
movies["genres"] =movies["genres"].apply(convert)
# Out:
# <ipython-input-25-1cc0e65cb154>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["genres"] =movies["genres"].apply(convert)

# %%
movies.head(1)
# Out:
#    movie_id                                           overview   title  \
# 0     19995  In the 22nd century, a paraplegic Marine is di...  Avatar
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
movies["keywords"] = movies["keywords"].apply(convert)
# Out:
# <ipython-input-27-930b7b463feb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies["keywords"] = movies["keywords"].apply(convert)

# %%
movies["cast"][1]
# Out:
# '[{"cast_id": 4, "character": "Captain Jack Sparrow", "credit_id": "52fe4232c3a36847f800b50d", "gender": 2, "id": 85, "name": "Johnny Depp", "order": 0}, {"cast_id": 5, "character": "Will Turner", "credit_id": "52fe4232c3a36847f800b511", "gender": 2, "id": 114, "name": "Orlando Bloom", "order": 1}, {"cast_id": 6, "character": "Elizabeth Swann", "credit_id": "52fe4232c3a36847f800b515", "gender": 1, "id": 116, "name": "Keira Knightley", "order": 2}, {"cast_id": 12, "character": "William \\"Bootstrap Bill\\" Turner", "credit_id": "52fe4232c3a36847f800b52d", "gender": 2, "id": 1640, "name": "Stellan Skarsg\\u00e5rd", "order": 3}, {"cast_id": 10, "character": "Captain Sao Feng", "credit_id": "52fe4232c3a36847f800b525", "gender": 2, "id": 1619, "name": "Chow Yun-fat", "order": 4}, {"cast_id": 9, "character": "Captain Davy Jones", "credit_id": "52fe4232c3a36847f800b521", "gender": 2, "id": 2440, "name": "Bill Nighy", "order": 5}, {"cast_id": 7, "character": "Captain Hector Barbossa", "credit_id": "52fe4232c3a36847f800b519", "gender": 2, "id": 118, "name": "Geoffrey Rush", "order": 6}, {"cast_id": 14, "character": "Admiral James Norrington", "credit_id": "52fe4232c3a36847f800b535", "gender": 2, "id": 1709, "name": "Jack Davenport", "order": 7}, {"cast_id": 13, "character": "Joshamee Gibbs", "credit_id": "52fe4232c3a36847f800b531", "gender": 2, "id": 2449, "name": "Kevin McNally", "order": 8}, {"cast_id": 11, "character": "Lord Cutler Beckett", "credit_id": "52fe4232c3a36847f800b529", "gender": 2, "id": 2441, "name": "Tom Hollander", "order": 9}, {"cast_id": 19, "character": "Tia Dalma", "credit_id": "52fe4232c3a36847f800b549", "gender": 1, "id": 2038, "name": "Naomie Harris", "order": 10}, {"cast_id": 8, "character": "Governor Weatherby Swann", "credit_id": "52fe4232c3a36847f800b51d", "gender": 2, "id": 378, "name": "Jonathan Pryce", "order": 11}, {"cast_id": 37, "character": "Captain Teague Sparrow", "credit_id": "52fe4232c3a36847f800b5b3", "gender": 2, "id": 1430, "name": "Keith Richards", "order": 12}, {"cast_id": 16, "character": "Pintel", "credit_id": "52fe4232c3a36847f800b53d", "gender": 2, "id": 1710, "name": "Lee Arenberg", "order": 13}, {"cast_id": 15, "character": "Ragetti", "credit_id": "52fe4232c3a36847f800b539", "gender": 2, "id": 1711, "name": "Mackenzie Crook", "order": 14}, {"cast_id": 18, "character": "Lieutenant Theodore Groves", "credit_id": "52fe4232c3a36847f800b545", "gender": 2, "id": 4031, "name": "Greg Ellis", "order": 15}, {"cast_id": 55, "character": "Cotton", "credit_id": "57e28d2ec3a3681a01005b5c", "gender": 2, "id": 1715, "name": "David Bailie", "order": 16}, {"cast_id": 17, "character": "Marty", "credit_id": "52fe4232c3a36847f800b541", "gender": 2, "id": 4030, "name": "Martin Klebba", "order": 17}, {"cast_id": 57, "character": "Ian Mercer", "credit_id": "57e28d78c3a36808b900bf4f", "gender": 0, "id": 939, "name": "David Schofield", "order": 18}, {"cast_id": 62, "character": "Scarlett", "credit_id": "57e28ec5c3a3681a50005855", "gender": 1, "id": 2450, "name": "Lauren Maher", "order": 19}, {"cast_id": 63, "character": "Giselle", "credit_id": "57e28ed692514123f5005635", "gender": 1, "id": 2452, "name": "Vanessa Branch", "order": 20}, {"cast_id": 60, "character": "Mullroy", "credit_id": "57e28db2c3a3681a01005bc7", "gender": 2, "id": 1714, "name": "Angus Barnett", "order": 21}, {"cast_id": 59, "character": "Murtogg", "credit_id": "57e28da192514118f7006008", "gender": 0, "id": 1713, "name": "Giles New", "order": 22}, {"cast_id": 58, "character": "Tai Huang", "credit_id": "57e28d8ec3a3681a01005bab", "gender": 2, "id": 22075, "name": "Reggie Lee", "order": 23}, {"cast_id": 64, "character": "Henry Turner", "credit_id": "57e29119925141151100a6cc", "gender": 2, "id": 61259, "name": "Dominic Scott Kay", "order": 24}, {"cast_id": 39, "character": "Mistress Ching", "credit_id": "52fe4232c3a36847f800b5bd", "gender": 1, "id": 33500, "name": "Takayo Fischer", "order": 25}, {"cast_id": 40, "character": "Lieutenant Greitzer" ...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
# <ipython-input-31-c8a573c9e007>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(convert)
#    movie_id                                           overview  \
# 0     19995  In the 22nd century, a paraplegic Marine is di...
# 1       285  Captain Barbossa, long believed to be dead, ha...
# 2    206647  A cryptic message from Bond’s past sends him o...
# 3     49026  Following the death of District Attorney Harve...
# 4     49529  John Carter is a war-weary, former military ca...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)
# Out:
# <ipython-input-33-1e2791f73e30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id                                           overview  \
# 427      45243  The Hangover crew heads to Thailand for Stu's ...
# 4433     29146  An experiment on a simpleton turns him into a ...
# 1595     76489  While trying to save their childhood orphanage...
# 2089       840  After an encounter with UFOs, a line worker fe...
# 2328     60307  Back in middle school after summer vacation, G...
#
#                                     title                             genres  \
# 427                  The Hangover Part II                           [Comedy]
# 4433                               Charly  [Drama, Romance, Science Fiction]
# 1595                    The Three Stooges                           [Comedy]
# 2089   Close Encounters of the Third Kind           [Science Fiction, Drama]
# 2328  Diary of a Wimpy Kid: Rodrick Rules                   [Family, Comedy]
#
#                                                keywords  \
# 427   [sun glasses, interpol, undercover cop, hangov...
# 4433     [experiment, mouse, intelligence test, genius]
# 1595                             [duringcreditsstinger]
# 2089  [indiana, obsession, extraterrestrial technolo...
# 2328                    [based on novel, middle school]
#
#                                                    cast  \
# 427   [Bradley Cooper, Ed Helms, Zach Galifianakis, ...
# 4433  [Cliff Robertson, Claire Bloom, Lilia Skala, L...
# 1595  [Sean Hayes, Will Sasso, Chris Diamantopoulos,...
# 2089  [Richard Dreyfuss, François Truffaut, Teri Gar...
# 2328  [Zachary Gordon, Devon Bostick, Rachael Harris...
#
#                                   crew
# 427                    [Todd Phillips]
# 4433                    [Ralph Nelson]
# 1595  [Bobby Farrelly, Peter Farrelly]
# 2089                [Steven Spielberg]
# 2328                    [David Bowers]

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())
# Out:
# <ipython-input-35-3bf62826a184>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']
# Out:
# <ipython-input-36-d64bc4c70271>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies.head()
# Out:
#    movie_id                                           overview  \
# 0     19995  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1       285  [Captain, Barbossa,, long, believed, to, be, d...
# 2    206647  [A, cryptic, message, from, Bond’s, past, send...
# 3     49026  [Following, the, death, of, District, Attorney...
# 4     49529  [John, Carter, is, a, war-weary,, former, mili...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast                 crew  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     [Gore Verbinski]
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         [Sam Mendes]
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  [Christopher Nolan]
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     [Andrew Stanton]
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)
# Out:
# <ipython-input-39-aea3176ce85e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['cast'] = movies['cast'].apply(collapse)
# <ipython-input-39-aea3176ce85e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['crew'] = movies['crew'].apply(collapse)
# <ipython-input-39-aea3176ce85e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['genres'] = movies['genres'].apply(collapse)
# <ipython-input-39-aea3176ce85e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head(1)
# Out:
#    movie_id                                           overview   title  \
# 0     19995  [In, the, 22nd, century,, a, paraplegic, Marin...  Avatar
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                                 cast            crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...  [JamesCameron]
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %% [markdown]
# # Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
from sklearn.preprocessing import normalize
import numpy as np

# Normalize vectors to unit length
vector_normalized = normalize(vector)

# %%
similarity = cosine_similarity(vector)

# %%
similarity2 = np.dot(vector_normalized, vector_normalized.T)

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# np.int64(744)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
def recommend2(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity2[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gandhi')
# Out:
# Lawrence of Arabia
# Public Enemies
# Superman
# Sands of Iwo Jima
# The Elephant Man

# %%
recommend('Superman')
# Out:
# The Greatest Story Ever Told
# Superman II
# Gandhi
# The Fifth Element
# Hoffa

# %%
recommend2('Gandhi')
# Out:
# Lawrence of Arabia
# Public Enemies
# Superman
# Sands of Iwo Jima
# The Elephant Man

# %%
import pickle

# %%
pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(similarity2,open('similarity2.pkl','wb'))

# %% [markdown]
# # Lets Integrate AI
#
# We will use Open AI api to call gpt-4o-mini to be able to give like an explainer as to why these movies were recommended.
#
# We will use Deepseek as well to view the responses and compare the two, and see how they fair.

# %%
# For Open ai
import openai
from openai import OpenAI
from google.colab import userdata

openai.api_key = userdata.get('OPENAI_API_KEY')
openai = OpenAI(api_key=openai.api_key)

#sample_call
response = openai.responses.create(
    model="gpt-4.1",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# Under a blanket of twinkling stars, a gentle unicorn tiptoed through the moonlit forest, leaving a trail of magical dreams for every sleeping child.

# %%
#Lets make the markdown a bit more beautiful

from IPython.display import Markdown, display

# %%
#for deep seek
deepseek_api_key = userdata.get('DEEPSEEK_API_KEY')

dp = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com")
#sample_calls

def reply():
  response_deep = dp.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello, explain with markdown why life is good with LG. Two H1"},
    ],
    stream=False
)

  print(response_deep.choices[0].message.content)

# %%
responded = reply

# %%
def get_recommendations(movie_title):

    index = new[new['title'] == movie_title].index[0]
    distances = sorted(list(enumerate(similarity2[index])), reverse=True, key=lambda x: x[1])
    recommended_movies = [new.iloc[i[0]].title for i in distances[1:6]]
    return recommended_movies

# %%
from IPython.display import Markdown, display

# %%
def explain_recommendations(movie_title, recommended_movies, ai_model="openai"):

    recommended_movies_str = ", ".join(recommended_movies)
    user_prompt = f"""
    Explain why the following movies were recommended based on the movie
     '{movie_title}': {recommended_movies_str}. Focus on potential thematic, genre, or plot similarities.


     """

    system_prompt = f"""
    you are helpful assistant that understands movies and you know how to recommend and draw pointers
    why movies are recommended.
     Be specific. Avoid Halucinations. Focus on potential thematic, genre, or plot similarities. Make it interesting
     and engaging and end with you should watch the movie.

     Reply in well structured markdown and easy to understand way.

     """

    if ai_model == "openai":
        try:
            response = openai.chat.completions.create(
                model="gpt-4o-mini", # Using gpt-4o-mini as per the user's comment
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt},
                ]
            )
            return response.choices[0].message.content
        except Exception as e:
            return f"Error with OpenAI API: {e}"
    elif ai_model == "deepseek":
        try:
            response_deep = dp.chat.completions.create(
                model="deepseek-chat",
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt},
                ]
            )
            return response_deep.choices[0].message.content
        except Exception as e:
            return f"Error with Deepseek API: {e}"
    else:
        return "Invalid AI model specified. Choose 'openai' or 'deepseek'."

# %%
display(Markdown(explain_recommendations('Gandhi', get_recommendations('Gandhi'), ai_model="openai")))
# Out:
# Certainly! Below are the reasons why each of the recommended movies is thematically, genre-wise, or plot-wise similar to *Gandhi*.
#
# ### 1. **Lawrence of Arabia (1962)**
#
# - **Theme of Leadership and Identity**: Both films explore the complexities of leadership in turbulent political landscapes. Just as Gandhi navigates the challenges of leading India towards independence, T.E. Lawrence's adventures reflect a struggle between self-identity and the impact he has on others.
#
# - **Epic Scope**: Both films are set against vast historical backdrops, showcasing the personal and political transformations of the protagonists. They emphasize the significance of individual actions on larger historical events.
#
# - **Cinematic Style**: *Lawrence of Arabia* utilizes sweeping cinematography that mirrors the grand vision of *Gandhi*, allowing audiences to engage with the epic nature of both stories.
#
# **You should watch this movie** for its rich storytelling and similarities in the exploration of influential figures.
#
# ---
#
# ### 2. **Public Enemies (2009)**
#
# - **Historical Context**: *Public Enemies* provides a portrayal of American history during the Great Depression, focusing on crime and the fight against injustice, similar to how *Gandhi* depicts the struggle against British colonial rule.
#
# - **Character Driven**: Both movies dive deep into the lives of influential figures – Mahatma Gandhi and John Dillinger. Each character is portrayed with nuanced humanity, depicting their motivations, struggles, and ethical dilemmas.
#
# - **Conflict and Resolution**: The films explore themes of resistance and rebellion, showcasing how individuals respond to oppression. This mirrors Gandhi's philosophy of nonviolent resistance against colonial forces.
#
# **You should watch this movie** for its gripping narrative and its connection to historical struggle.
#
# ---
#
# ### 3. **Superman (1978)**
#
# - **Heroism and Morality**: Both *Gandhi* and *Superman* center around themes of heroism, yet they approach them from different perspectives. Gandhi represents moral courage against oppression, while Superman embodies the struggle between good and evil.
#
# - **Symbolism of Hope**: Just as Gandhi symbolizes the hope for Indian independence and the fight for justice, Superman represents hope for humanity. Both characters inspire those around them towards a better future.
#
# - **Cultural Impact**: Both films have had significant cultural impacts in their respective narratives, shaping how society views heroism, justice, and the fight against tyranny.
#
# **You should watch this movie** for its powerful themes of hope and morality.
#
# ---
#
# ### 4. **Sands of Iwo Jima (1949)**
#
# - **War and Leadership**: While *Gandhi* deals with non-violent resistance, it is deeply rooted in the context of colonial oppression which can be juxtaposed against *Sands of Iwo Jima*, exploring the leadership dynamics in a critical battle of World War II.
#
# - **Sacrifice and Duty**: The theme of sacrifice for a greater cause resonates in both films. Just as Gandhi sacrifices his personal comforts for India’s freedom, the soldiers in *Sands of Iwo Jima* embody the same spirit of sacrifice for their country.
#
# - **Character Study**: Both films provide rich character studies that illustrate the complexities of human experience amid turmoil and conflict.
#
# **You should watch this movie** for its nuanced portrayal of sacrifice in wartime.
#
# ---
#
# ### 5. **The Elephant Man (1980)**
#
# - **Human Rights and Dignity**: Both *The Elephant Man* and *Gandhi* highlight the importance of human rights and dignity. They address societal prejudice and the struggle for acceptance, shedding light on characters marginalized by society.
#
# - **Biographical Narratives**: Both films are based on true stories and depict the lives of extraordinary individuals who overcame immense odds. Their journeys toward respect and understanding resonate deeply.
#
# - **Emotional Depth**: Both films evoke powerful emotional responses as they explore the humanity within suffering, encouraging audiences to empathize with the characters' plights.
#
# **You should watch this movie** for its rich emotional storytelling and themes of humanity.
#
# ---
#
# In conclusion, each of these films shares thematic resonances with *Gandhi*, whether through their exploration of human rights, leadership, moral dilemmas, or the struggle for justice. They provide rich narratives that complement the profound messages found in *Gandhi*. **You should watch these movies!**

# %%
# prompt: mAke display a function from above

def display_explanation(movie_title, ai_model="openai"):
    recommended_movies = get_recommendations(movie_title)
    explanation = explain_recommendations(movie_title, recommended_movies, ai_model=ai_model)
    display(Markdown(explanation))

# %%
# Example Usage:

movie_to_explain = 'Gandhi'
recommended = get_recommendations(movie_to_explain)

print(f"Recommended movies for '{movie_to_explain}': {recommended}")

explanation = explain_recommendations(movie_to_explain, recommended, ai_model="openai")
openai_explanation = display(Markdown(explanation))
print("\nOpenAI Explanation:")
print(openai_explanation)

explanation_deepseek = explain_recommendations(movie_to_explain, recommended, ai_model="deepseek")
deepseek_explanation = display(Markdown(explanation_deepseek))
print("\nDeepseek Explanation:")
deepseek_explanation
# Out:
# Recommended movies for 'Gandhi': ['Lawrence of Arabia', 'Public Enemies', 'Superman', 'Sands of Iwo Jima', 'The Elephant Man']
# Certainly! Below are explanations for why each of the following movies—**Lawrence of Arabia**, **Public Enemies**, **Superman**, **Sands of Iwo Jima**, and **The Elephant Man**—is recommended based on similarities with **Gandhi**. I'll highlight the thematic, genre, and plot connections that can deepen your appreciation for these films.
#
# ---
#
# ### 1. **Lawrence of Arabia (1962)**
# - **Thematic Similarities**: Both films explore the life of a prominent historical figure who is involved in political and military transformations. Lawrence's journey mirrors Gandhi's in terms of activism and the pursuit of freedom for oppressed peoples.
# - **Character Development**: The protagonists in both films experience significant personal and ideological conflicts, highlighting the complexities of their characters as they navigate their respective roles in tumultuous times.
# - **Visual Epic**: Just as *Gandhi* presents breathtaking landscapes and historical settings, *Lawrence of Arabia* showcases the stunning desert vistas, enhancing the epic quality of their narratives.
#
# **You should watch *Lawrence of Arabia* if you appreciated the compelling storytelling of Gandhi's life and the majestic cinematography.**
#
# ---
#
# ### 2. **Public Enemies (2009)**
# - **Thematic Similarities**: While focusing on the life of notorious bank robber John Dillinger, this film touches on themes of crime, justice, and the societal impact of individuals rebelling against the system, parallel to Gandhi’s rebellion against colonial oppression.
# - **Complex Antagonists**: Both films present characters that are not purely good or evil. Just as Gandhi's portrayal illustrates his flaws, Dillinger is portrayed with both charisma and a darker edge, raising questions about heroism.
# - **Era of Change**: The early 20th-century backdrop of *Public Enemies* reflects societal and political upheaval, similar to the atmosphere during Gandhi’s activism for independence in India.
#
# **You should watch *Public Enemies* to witness how individuals can influence societal change, even when perceived as outlaws.**
#
# ---
#
# ### 3. **Superman (1978)**
# - **Thematic Similarities**: *Superman* explores the notion of a singular figure striving to make the world a better place. Like Gandhi's quest for peace and justice, Superman's objective is to protect and uplift humanity.
# - **Symbolism of Hope**: Both protagonists serve as symbols of hope; Gandhi represents non-violent resistance, while Superman embodies truth and justice, appealing to similar ideals of heroism and moral integrity.
# - **Conflict of Ideals**: Just as Gandhi faces endless challenges in his pursuit for peace, Superman grapples with the struggle between his ideals and the harsh realities of the world around him.
#
# **You should watch *Superman* if you're interested in heroic journeys that resonate with the ideals of justice and compassion like those seen in *Gandhi*.**
#
# ---
#
# ### 4. **Sands of Iwo Jima (1949)**
# - **Thematic Similarities**: This war film examines sacrifice, duty, and leadership in the face of conflict, resonating with the themes of perseverance found in Gandhi's life. Both stories emphasize moral courage amid dire circumstances.
# - **Character Arcs**: The journey of the protagonists in both films showcases their development from ordinary individuals into symbols of resistance and strength, highlighting the personal costs of their missions.
# - **Historical Context**: Just like *Gandhi* captures the essence of India’s struggle for independence, *Sands of Iwo Jima* presents the American struggle during WWII, creating a context of resilience in the face of tyranny.
#
# **You should watch *Sands of Iwo Jima* to appreciate the portrayal of determination and human spirit in times of conflict akin to Gandhi’s own journey.**
#
# ---
#
# ### 5. **The Elephant Man (1980)**
# - **Thematic Similarities**: Both films showcase stories of marginalized individuals who seek dignity and understanding in a world that often overlooks them. *The Elephant Man* focuses on Joseph Merrick's struggle for acceptance, paralleling Gandhi’s fight against social injustice.
# - **Human Dignity**: Central to both narratives is the theme of human dignity and respect, emphasizing the importance of compassion and understanding towards those who are different or oppressed.
# - **Emotional Depth**: Like *Gandhi*, this film takes viewers on a deeply emotional journey, compelling them to reflect on society’s treatment of the vulnerable.
#
# **You should watch *The Elephant Man* if you value narratives that highlight humanity's complexities and the fight for compassion and equality, much like the story of Gandhi.**
#
# ---
#
# In conclusion, each of these films offers unique perspectives on themes of heroism, justice, and personal sacrifice, making them excellent companions to *Gandhi*. You should definitely watch them!
# OpenAI Explanation:
# None
# ```markdown
# # Movie Recommendations Based on *Gandhi*
#
# ## **1. Lawrence of Arabia (1962)**
# **Why?**
# - **Thematic Similarity**: Both films explore historical figures who led transformative movements (Gandhi in India, T.E. Lawrence in Arabia).
# - **Epic Scale**: Sweeping cinematography and grand storytelling about colonialism and resistance.
# - **Character Depth**: Complex protagonists who challenge oppressive systems.
# **You should watch it if** you loved *Gandhi*'s historical depth and moral struggle.
#
# ## **2. Public Enemies (2009)**
# **Why?**
# - **Moral Complexity**: Like Gandhi, John Dillinger is a polarizing figure—seen as a criminal by some, a folk hero by others.
# - **Societal Impact**: Both films examine how individuals disrupt systemic power (British rule vs. the American justice system).
# **You should watch it if** you're interested in rebellion against authority.
#
# ## **3. Superman (1978)**
# **Why?**
# - **Symbol of Hope**: Gandhi and Superman both represent idealism and justice.
# - **Sacrifice for Greater Good**: Superman’s selflessness mirrors Gandhi’s nonviolent resistance.
# **You should watch it if** you admire *Gandhi*’s inspirational leadership.
#
# ## **4. Sands of Iwo Jima (1949)**
# **Why?**
# - **Leadership & Duty**: Like Gandhi, Sgt. Stryker leads through conviction, though in a militaristic context.
# - **Historical Struggle**: Both films depict pivotal moments in history (Indian independence vs. WWII).
# **You should watch it if** you appreciate films about perseverance.
#
# ## **5. The Elephant Man (1980)**
# **Why?**
# - **Human Dignity**: Both Gandhi and John Merrick fight against dehumanization.
# - **Compassion vs. Cruelty**: Themes of societal prejudice and empathy.
# **You should watch it if** *Gandhi* moved you with its humanity.
#
# **Final Thought**: Each film, in its own way, echoes *Gandhi*’s themes of struggle, leadership, and moral courage. Pick one and dive in!
# ```
# Deepseek Explanation:

# %%
#!pip install gradio -q

import gradio as gr

def movie_recommendation_app(movie_title, ai_model):
  recommended_movies = get_recommendations(movie_title)
  recommendations_str = "\n".join(recommended_movies)
  explanation3 = explain_recommendations(movie_title, recommended_movies, ai_model=ai_model)
  explained = display(Markdown(explanation3))
  return recommendations_str, explained

movie_titles = new['title'].tolist()

# %%
movie_recommendation_app("Superman", "openai")
# Out:
# Certainly! Let's explore the thematic, genre, and plot similarities among the movies recommended based on **"Superman"**:
#
# ### 1. **The Greatest Story Ever Told**
# - **Theme of Sacrifice and Heroism**: Like Superman, who embodies hope and selflessness, this film portrays the life of Jesus Christ, emphasizing themes of sacrifice, redemption, and heroism in the face of adversity.
# - **Epic Storytelling**: Both films tackle grand narratives that inspire audiences, with larger-than-life characters who strive to impart goodness in the world.
# - **Moral Lessons**: Just as Superman teaches moral lessons about justice and righteousness, "The Greatest Story Ever Told" provides insight into faith, leadership, and the impact of one individual on humanity.
#
# **Conclusion**: If you appreciate Superman's moral complexity and his role as a savior, you will find similar depth in “The Greatest Story Ever Told.”
#
# ### 2. **Superman II**
# - **Direct Sequel**: As a direct continuation of Superman's story, this film expands upon Clark Kent’s dual identity, exploring the themes of love, vulnerability, and personal sacrifice.
# - **Conflict with Evil**: Just like the first film, it showcases Superman battling formidable foes. This sequel raises the stakes, delving deeper into the tension between power and responsibility.
# - **Exploration of Identity**: Characters in both films grapple with their identities, whether it is Superman’s struggle between his Kryptonian heritage and his human upbringing, or the villains' motivations.
#
# **Conclusion**: If you loved the original for its foundational themes and character development, you should definitely watch "Superman II" to see how the story progresses.
#
# ### 3. **Gandhi**
# - **Theme of Non-Violence and Justice**: Similar to Superman’s dedication to fighting for justice, Gandhi’s journey showcases the power of peaceful resistance against oppression.
# - **Impactful Leadership**: Both figures serve as leaders who inspire change in their worlds, embodying moral conviction and the desire to uplift marginalized communities.
# - **Biographical Elements**: While Superman is fictional, the biographical portrayal of Gandhi presents a blend of factual and inspirational storytelling that resonates with the heroic journey.
#
# **Conclusion**: If you admire Superman for his noble ideals, you'll appreciate the historical significance of Gandhi’s role in social justice and moral leadership.
#
# ### 4. **The Fifth Element**
# - **Hero's Journey**: This film also features a central hero who must save the world, akin to Superman. The unconventional and humorous approach to the sci-fi genre parallels Superman's sometimes lighter moments amidst serious themes.
# - **Alien Heritage**: Much like Superman’s origin from a distant planet, "The Fifth Element" explores themes of alien beings and the fusion of different worlds to create a narrative around unity and saving humanity.
# - **Good vs. Evil**: The conflict against evil forces is prominent in both stories, offering a battle against overwhelming odds for the sake of the greater good.
#
# **Conclusion**: If you enjoy the fantastical elements and heroism found in "Superman," you will definitely be captivated by "The Fifth Element."
#
# ### 5. **Hoffa**
# - **Complex Characterization**: Like Clark Kent who has to balance his powers and true identity, Jimmy Hoffa's character navigates the complexities of morality within the labor movement.
# - **Themes of Power and Corruption**: The film explores themes of power dynamics and ethical dilemmas, mirroring Superman’s struggles against corrupt figures and institutions.
# - **Real-Life Inspiration**: Just as Superman reflects societal issues, Hoffa’s story addresses real labor struggles, providing a gritty parallel to the idealized heroism of Superman.
#
# **Conclusion**: If you appreciate films that delve into the moral complexities of power and ambition, “Hoffa” will provide a grounding experience amid the soaring ideals of Superman.
#
# ---
#
# **Final Recommendation**: Each of these films resonates with elements found in "Superman," whether through themes of heroism, personal sacrifice, moral responsibility, or the struggle against evil. You should watch each of these movies to discover the varied approaches to storytelling that share the essence of what it means to be a hero.
# ('The Greatest Story Ever Told\nSuperman II\nGandhi\nThe Fifth Element\nHoffa',
#  None)

# %% [markdown]
# # Gradio App

# %%
iface = gr.Interface(
    fn=movie_recommendation_app,
    inputs=[
        gr.Dropdown(movie_titles, label="Select a Movie"),
        gr.Radio(["openai", "deepseek"], label="Select AI Model for Explanation")
    ],
    outputs=[
        gr.Textbox(label="Recommended Movies"),
        gr.Textbox(label="Explanation from AI")
    ],
    title="Movie Recommendation System with AI Explanation",
    description="""Select a movie amd get recommendations, select an AI model to get an explanation why the movies are recommended.
                    The cosine similarity encode each title with the overview of each movie, then
                    giving AI models to explain to users why it is recommended

                  """
)

iface.launch(debug=True, share=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://2d93f74d6ebf3d4f5f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2d93f74d6ebf3d4f5f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# # Movie Recommendations Based on *Avatar*
#
# Here’s why these films were recommended—each shares thematic, genre, or plot elements with *Avatar* while offering unique twists.
#
# ## **1. Star Trek Into Darkness (2013)**
# - **Thematic Similarity**: Explores colonization, militarization, and ethical dilemmas in space. Like *Avatar*, it questions authority and the cost of war.
# - **Visual Spectacle**: High-budget sci-fi with stunning CGI and immersive world-building.
# - **Conflict Over Resources**: The villain’s motives tie into control and power, much like the RDA’s pursuit of unobtanium.
# - **Why Watch?** If you loved *Avatar*’s sci-fi politics and action, this delivers a similar adrenaline rush with a Star Trek twist.
#
# ## **2. Aliens (1986)**
# - **Colonialism & Corporate Greed**: The Weyland-Yutani Corporation mirrors the RDA—both exploit alien worlds for profit.
# - **Human vs. Alien Conflict**: Like the Na’vi, the xenomorphs are a formidable, misunderstood species fighting back.
# - **Strong Protagonist**: Ripley (like Jake Sully) becomes an unlikely hero defending the oppressed.
# - **Why Watch?** A gritty, action-packed take on survival against overwhelming odds—perfect for *Avatar* fans who love high-stakes battles.
#
# ## **3. The Thing (1982)**
# - **Alien World Dangers**: Both films involve humans confronting the unknown in hostile environments (Pandora vs. Antarctica).
# - **Paranoia & Survival**: The Thing’s shape-shifting horror parallels *Avatar*’s themes of trust and deception.
# - **Why Watch?** If you enjoyed *Avatar*’s tension but want a darker, horror-infused twist, this is a must.
#
# ## **4. Armageddon (1998)**
# - **Humanity vs. Nature**: Like *Avatar*, it pits humans against forces beyond their control (asteroid vs. Pandora’s ecosystem).
# - **Teamwork & Sacrifice**: Both films emphasize unlikely heroes banding together for survival.
# - **Why Watch?** For those who loved *Avatar*’s epic scale and emotional stakes, *Armageddon* delivers explosive action with heart.
#
# ## **5. The Dark Knight (2008)**
# - **Moral Complexity**: Like *Avatar*, it questions heroism—Jake Sully’s betrayal vs. Batman’s ethical struggles.
# - **Corporate & Political Corruption**: The RDA and Gotham’s villains both represent unchecked greed.
# - **Why Watch?** If *Avatar*’s conflict between idealism and corruption intrigued you, *The Dark Knight* takes it deeper with a gripping crime saga.
#
# ### **Final Verdict**
# Each of these films expands on *Avatar*’s core themes—whether through sci-fi battles, survival horror, or moral dilemmas. **Pick one and dive in!** 🎬

# %% [markdown]
# ## Another Approach

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
TF = TfidfVectorizer(max_features=5000, stop_words='english')

# %%
vector2 = TF.fit_transform(new['tags']).toarray()

# %%
vector2

# %%
vector2.shape

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity3 = cosine_similarity(vector2)

# %%
def recommend3(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend2('Superman')

# %% [markdown]
# # FAISS

# %%
# !pip install faiss-cpu

# %%
import faiss
import numpy as np

# Assume vector is your feature matrix: shape = (n_movies, embedding_dim)
# Normalize if using cosine similarity (turns cosine into dot product)
vector = vector.astype('float32')  # FAISS needs float32
faiss.normalize_L2(vector)

# %%
# Build index
index = faiss.IndexFlatIP(vector.shape[1])
index.add(vector)

# %%
def recommend4(movie):
    # Get the index of the selected movie
    idx = new[new['title'] == movie].index[0]

    # Search the top 6 similar (includes the movie itself)
    D, I = index.search(vector[idx:idx+1], 6)

    # Print top 5 recommended movie titles (skip the input movie itself)
    for i in I[0][1:6]:
        print(new.iloc[i].title)

# %%
recommend4("Gandhi")

# %%
import faiss

# Save the FAISS index to a file
faiss.write_index(index, "movie_index.faiss")
